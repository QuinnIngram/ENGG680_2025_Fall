# %% [markdown]
# # **ENGG680 - Introduction to Digital Engineering**
# ## *Lab Assignment 1: Using Git and Python for Collaborative Coding in Google Colab & Least Square Application*
# ### (100 Marks)

# %% [markdown]
# ## Preliminary: Certificate of Work
# ### (5 Marks)

# %% [markdown]
# *We, the undersigned, certify that this is our own work, which has been done expressly for this course, either without the assistance of any other party or where appropriate we have acknowledged the work of others. Further, we have read and understood the section in the university calendar on plagiarism/cheating/other academic misconduct and we are aware of the implications thereof. We request that the total mark for this assignment be distributed as follows among group members:*

# %% [markdown]
# |          | First Name | Last Name | Signature (Full Name, Date) | Hours | Contribution % |
# |----------|------------|-----------|-----------------------------|-------|----------------|
# | Member 1: | Quinn | Ingram | Quinn Ingram, October 12, 2025 | 6 | 25% |
# | Member 2: | Akhimien | Ehizokhale | AE, October 22, 2025 | 3 | 25% |
# | Member 3: | Alice | Gomez | Alice Gomez, October 24, 2025 | 6 | 25% |
# | Member 4: | Ireayomide | Otudeko | Ireayomide Otudeko | 2 | 25% |

# %% [markdown]
# ## Part 1: Printing to the Console
# ### (4 Marks)

# %%
# In the space below, please print "Hello, World! Welcome to the Student Gradebook Management System."
print ("Hello, World! Welcome to the Student Gradebook Management System.")
# Out:
# Hello, World! Welcome to the Student Gradebook Management System.

# %%
# Fill in your information using the defined variables below:
# (1 mark)
lab_group_number = 14
intake_year = 2025
intake_semester = "Fall" #"Fall" or "Winter"

# Using f-strings and the variables above, print "This is implemented by Group <lab_group_number>, for ENGG680 <intake_semester> of <intake_year>"
# (1 marks)
our_group = f"This is implemented by Group {lab_group_number}, for ENGG680 {intake_semester} of {intake_year}"
print(our_group)
# Out:
# This is implemented by Group 14, for ENGG680 Fall of 2025

# %%
# Similarly, create variables for each of your group members (eg. member_1, member_2....) and assign them your first names.
# Then, using f-strings and the variables above, print the following sentence:
# "Our Group Members include <member_1>, <member_2>, ..."
# (1 marks)
member_1 = "Quinn"
member_2 = "Akhimien"
member_3 = "Alice"
member_4 = "Ireayomide"
Group_members = f"Our Group Members include {member_1}, {member_2}, {member_3}, and {member_4}"
print(Group_members)
# Out:
# Our Group Members include Quinn, Akhimien, Alice, and Ireayomide

# %%
# Use indexing to print "The subjects involved in this grading system is English and Math." using "subjects" below.
# (1 marks)
subjects = ("English", "Math")
print(f"The subjects involved in this grading system is {subjects[0]} and {subjects[1]}.")
# Out:
# The subjects involved in this grading system is English and Math.

# %% [markdown]
# ## Part 2: Python Fundamentals
# ### (11 Marks)

# %%
# Lists (2 marks)

# 1. Create a list of any 5 cities in Alberta.
#
Alberta_cities = ["Calgary", "Edmonton", "Red Deer", "Jasper", "Grande Prairie"]

# 2. Print the list
#
print (Alberta_cities)

# 3. Add a new city to list.
#
Alberta_cities.append("Lethbridge")

# 4. Remove the second city using either remove() or pop().
#
Alberta_cities.remove("Edmonton")

# 5. Sort the list alphabetically
#
Alberta_cities.sort()

# 6. Print your final list
#
print(Alberta_cities)
# Out:
# ['Calgary', 'Edmonton', 'Red Deer', 'Jasper', 'Grande Prairie']
# ['Calgary', 'Grande Prairie', 'Jasper', 'Lethbridge', 'Red Deer']

# %%
# Tuples (2 marks)

# 1. Create a tuple of 3 favorite numbers.
#
favorite_numbers = (5, 7, 10)

# 2. Print the tuple.
#
print(favorite_numbers)

# 3. Try to modify the second element. Does that work? Explain.
#
try:
    favorite_numbers[1] = 8
except TypeError:
    print("Tuples are immutable, so you cannot modify their elements.")
# Out:
# (5, 7, 10)
# Tuples are immutable, so you cannot modify their elements.

# %%
# Dictionaries (2 marks)

# 1. Create a dictionary representing a mini visa form with keys like:
# "Name", "File Number", "Country", "Visa Type", "Expiry Year"
# Assign fictional values to the keys.
# Note: Dictionaries can contain values of different data types.
#
visa_form = {
    "Name": "Samuel Victor",
    "File Number": "B7823",
    "Country": "Germany",
    "Visa Type": "Student",
    "Expiry Year": 2030
}
# 2. Print the dictionary
#
print(visa_form)
# 3. Add a new key "University" with a value
#
visa_form["University"] = "University of Calgary"
# 4. Update "Expiry Year" to a new year
#
visa_form["Expiry Year"] = 2031
# 5. Print the final dictionary
#
print(visa_form)
# Out:
# {'Name': 'Samuel Victor', 'File Number': 'B7823', 'Country': 'Germany', 'Visa Type': 'Student', 'Expiry Year': 2030}
# {'Name': 'Samuel Victor', 'File Number': 'B7823', 'Country': 'Germany', 'Visa Type': 'Student', 'Expiry Year': 2031, 'University': 'University of Calgary'}

# %%
# Sets (2 marks)

# Set 1
subjects1 = {"Math", "English", "Physics", "Biology", "History"}

# Set 2
subjects2 = {"Math", "English", "Chemistry", "Geography", "Physics"}

# Tip: Use f-strings to print clear messages along with your output.
# Eg. "Union: ", "Intersection: "

# 1. Print both the sets
#
print(subjects1)
print(subjects2)
# 2. Print the union of sets
#
Union = subjects1.union(subjects2)
print(f"The union of subjects 1 and subjects 2 is {Union}")

# 3. Print the intersection of sets
#
intersection = subjects1.intersection(subjects2)
print(f"The intersection of subjects 1 and subjects 2 is {intersection}")
# 4. Print the difference (subjects1 - subjects2)
#
difference = subjects1.difference(subjects2)
print(f"The difference between subjects 1 and subjects 2 is {difference}")
# Out:
# {'History', 'Math', 'English', 'Physics', 'Biology'}
# {'Math', 'English', 'Geography', 'Physics', 'Chemistry'}
# The union of subjects 1 and subjects 2 is {'History', 'English', 'Biology', 'Math', 'Geography', 'Physics', 'Chemistry'}
# The intersection of subjects 1 and subjects 2 is {'Physics', 'Math', 'English'}
# The difference between subjects 1 and subjects 2 is {'History', 'Biology'}

# %%
# Classes and Function (3 marks)

# Step 1: Create a class BankAccount.
# Add class attribute bankname="Canada Bank"
# Add 2 instance attributes: account_holder (string) & balance (float, default value 0.0)
class BankAccount:
  # class attribute
  bankname = "Canada Bank"
  # instance attributes
  def __init__(self, account_holder, balance=0.0):
    self.account_holder = account_holder
    self.balance = balance

  # Step 2: Add methods
  # 1. deposit(amount) -> Add amount to the balance
  def deposit(self, amount):
    self.balance += amount
    return f"You deposited ${amount} The new balance is: ${self.balance}"

  # 2. withdraw(amount) -> Subtract the amount if balance is sufficient, else print an error message
  def withdraw(self, amount):
    if self.balance >= amount:
      self.balance -= amount
      return f"You withdrew ${amount}, The new balance is: ${self.balance}"
    else:
      return "Insufficient funds."

  # 3. get_balance() -> Print Account holder's name and current balance
  def get_balance(self):
    return f"Account holder: {self.account_holder}, The current balance is: ${self.balance}"

  # 4. get_bankname() -> Print the class attribute (staticmethod)
  @staticmethod
  def get_bankname():
    return BankAccount.bankname

# Note: Use f-strings to display the amount and updated balance whenever you call deposit() or withdraw()


# Step 3: Test
# 1. Print the Bankname
print(BankAccount.get_bankname())

# 2. Create an object of BankAccount with your name and an initial balance of 1000
my_account = BankAccount("Ireayomide Otudeko", 1000.0)

# 3. Deposit 500
print(my_account.deposit(500.0))

# 4. Withdraw 200
print(my_account.withdraw(200.0))

# 5. Print the final balance
print(my_account.get_balance())
# Out:
# Canada Bank
# You deposited $500.0 The new balance is: $1500.0
# You withdrew $200.0, The new balance is: $1300.0
# Account holder: Ireayomide Otudeko, The current balance is: $1300.0

# %% [markdown]
# ## Part 3: Using Pandas for Data Management and Analytics
# ### (15 marks)

# %%
# In the space below, please import the Pandas library
import pandas as pd

# %%
# Load the student grade CSV files into DataFrames using the defined variables
# (1 marks)
df_english = pd.read_csv(r"C:\Users\quin4\OneDrive\Documents\UofC_Masters\ENGG680_python\Assignment files\Assignment_1\Github_cloned\ENGG680_2025_Fall\Lab_Assignment_1\studentGrades_English.csv")
df_math = pd.read_csv(r"C:\Users\quin4\OneDrive\Documents\UofC_Masters\ENGG680_python\Assignment files\Assignment_1\Github_cloned\ENGG680_2025_Fall\Lab_Assignment_1\studentGrades_Math.csv")

# %%
# Print the first 5 rows of df_english using the .head method
print(df_english.head(5))
# Out:
#   firstName  lastName  studentID  grade
# 0      Emma     Smith      10959     95
# 1    Sophia  Robinson      75175     88
# 2      Emma    Taylor      42257     87
# 3     David  Robinson      55148     86
# 4   Stephen     Curry      30303     90

# %%
# Print the first 5 rows of df_math using the .head method
print(df_math.head(5))
# Out:
#   firstName lastName  studentID  grade
# 0     James    Jones      87707     92
# 1     Sarah    Swift      61026     98
# 2      Anne    Clark      90449     99
# 3      Ryan   Thomas      62137     89
# 4    Daniel    White      25477     87

# %%
# Merging the DataFrames on 'studentID'
df_studentGrades = pd.merge(df_english, df_math, on='studentID', suffixes=('_English', '_Math'))

# %%
# Take a look at the data contained in the csv files. Why is studentID chosen as the key?
# (0.5 mark)
#print(df_studentGrades)

# StudentID is chosen as the key because it is a unique identifier for each student
# and allows for accurate matching of data between the files without duplication.

# %%
# You will notice that all the column names got suffixes except studentID.
# Explain why pandas didn't add suffixes to the studentID column.

# StudentID did not get a suffix because it is the common column used for merging
# the two DataFrames and adding a suffix would create ambiguity.

# %%
# Let's calculate the average GPA across the two classes for each student
df_studentGrades['GPA'] = df_studentGrades[['grade_English', 'grade_Math']].mean(axis=1)

# Now let's check the data! In the space below, please use the .head method to display the dataframe.
# (1 mark)
print(df_studentGrades.head(14))
# Out:
#    firstName_English lastName_English  studentID  grade_English  \
# 0               Emma            Smith      10959             95
# 1             Sophia         Robinson      75175             88
# 2               Emma           Taylor      42257             87
# 3              David         Robinson      55148             86
# 4            Stephen            Curry      30303             90
# 5           Isabella         Thompson      72824             88
# 6            Jasmine            Smith      70385             84
# 7              James            Jones      87707             76
# 8              Sarah            Swift      61026             80
# 9               Anne            Clark      90449             82
# 10              Ryan           Thomas      62137             92
# 11            Daniel            White      25477             91
# 12              Sara              Doe      47991             98
# 13           Matthew            White      25376             80
#
#    firstName_Math lastName_Math  grade_Math   GPA
# 0            Emma         Smith          90  92.5
# 1          Sophia      Robinson          95  91.5
# 2            Emma        Taylor          85  86.0
# 3           David      Robinson          87  86.5
# 4         Stephen         Curry          88  89.0
# 5        Isabella      Thompson          79  83.5
# 6         Jasmine         Smith          80  82.0
# 7           James         Jones          92  84.0
# 8           Sarah         Swift          98  89.0
# 9            Anne         Clark          99  90.5
# 10           Ryan        Thomas          89  90.5
# 11         Daniel         White          87  89.0
# 12           Sara           Doe          86  92.0
# 13        Matthew         White          85  82.5

# %%
# Do you notice a problem? The rows for first name and last name have been duplicated!
# .drop(columns=['<column_name1>','<column_name2>'] is a Pandas method that can be used to drop columns.
# In the space below, drop the first name and last name associated with the math .csv file.
# (2 mark)
df_studentGrades = df_studentGrades.drop(columns=['firstName_Math', 'lastName_Math'])

# %%
# Let's display the data again. Use an appropriate method (hint: already used before)
# (0.5 mark)
print(df_studentGrades.head(14))
# Out:
#    firstName_English lastName_English  studentID  grade_English  grade_Math  \
# 0               Emma            Smith      10959             95          90
# 1             Sophia         Robinson      75175             88          95
# 2               Emma           Taylor      42257             87          85
# 3              David         Robinson      55148             86          87
# 4            Stephen            Curry      30303             90          88
# 5           Isabella         Thompson      72824             88          79
# 6            Jasmine            Smith      70385             84          80
# 7              James            Jones      87707             76          92
# 8              Sarah            Swift      61026             80          98
# 9               Anne            Clark      90449             82          99
# 10              Ryan           Thomas      62137             92          89
# 11            Daniel            White      25477             91          87
# 12              Sara              Doe      47991             98          86
# 13           Matthew            White      25376             80          85
#
#      GPA
# 0   92.5
# 1   91.5
# 2   86.0
# 3   86.5
# 4   89.0
# 5   83.5
# 6   82.0
# 7   84.0
# 8   89.0
# 9   90.5
# 10  90.5
# 11  89.0
# 12  92.0
# 13  82.5

# %%
# Let's also rename the first and last names appropriately.
# Complete the code in the space below by replacing "<>" with the proper column name
# (1 mark)

df_studentGrades = df_studentGrades.rename(columns={
    'firstName_English': 'firstName',
    'lastName_English': 'lastName',
    'grade_English': 'englishGrade',
    'grade_Math': 'mathGrade'
    })

print(df_studentGrades.head(14))
# Out:
#    firstName  lastName  studentID  englishGrade  mathGrade   GPA
# 0       Emma     Smith      10959            95         90  92.5
# 1     Sophia  Robinson      75175            88         95  91.5
# 2       Emma    Taylor      42257            87         85  86.0
# 3      David  Robinson      55148            86         87  86.5
# 4    Stephen     Curry      30303            90         88  89.0
# 5   Isabella  Thompson      72824            88         79  83.5
# 6    Jasmine     Smith      70385            84         80  82.0
# 7      James     Jones      87707            76         92  84.0
# 8      Sarah     Swift      61026            80         98  89.0
# 9       Anne     Clark      90449            82         99  90.5
# 10      Ryan    Thomas      62137            92         89  90.5
# 11    Daniel     White      25477            91         87  89.0
# 12      Sara       Doe      47991            98         86  92.0
# 13   Matthew     White      25376            80         85  82.5

# %%
# Now let's find out some statistics about our student grades!
# Please use an appropriate Pandas method in the space below to display statistical values like
# mean, standard deviation, min, max, and others.
# (1 mark)

#Describe did not print anthing for the names columns because they are non-numeric strings
df_studentGrades.describe()
# Out:
#           studentID  englishGrade  mathGrade       GPA
# count     14.000000     14.000000  14.000000  14.00000
# mean   54086.714286     86.928571  88.571429  87.75000
# std    24610.266586      6.145221   5.918865   3.63609
# min    10959.000000     76.000000  79.000000  82.00000
# 25%    33291.500000     82.500000  85.250000  84.50000
# 50%    58087.000000     87.500000  87.500000  89.00000
# 75%    72214.250000     90.750000  91.500000  90.50000
# max    90449.000000     98.000000  99.000000  92.50000

# %%
# Do you notice a problem?
# Some statistics are not relevant. The average of studentIDs have no meaning in reality!
# Let's typecast each column appropriately so as to only get meaningful statistics.
# In the code below, replace '<>' by choosing between 'str' for string or 'float' for float
# to properly typecast each column.
# (1 marks)
df_studentGrades['studentID'] = df_studentGrades['studentID'].astype(str)
df_studentGrades['firstName'] = df_studentGrades['firstName'].astype(str)
df_studentGrades['lastName'] = df_studentGrades['lastName'].astype(str)
df_studentGrades['englishGrade'] = df_studentGrades['englishGrade'].astype(float)
df_studentGrades['mathGrade'] = df_studentGrades['mathGrade'].astype(float)
df_studentGrades['GPA'] = df_studentGrades['GPA'].astype(float)

# %%
# Now let's see our statistics!
df_studentGrades.describe()
# Out:
#        englishGrade  mathGrade       GPA
# count     14.000000  14.000000  14.00000
# mean      86.928571  88.571429  87.75000
# std        6.145221   5.918865   3.63609
# min       76.000000  79.000000  82.00000
# 25%       82.500000  85.250000  84.50000
# 50%       87.500000  87.500000  89.00000
# 75%       90.750000  91.500000  90.50000
# max       98.000000  99.000000  92.50000

# %%
# Now sort the merged dataframe so that it is in descending order based on GPA, and print it
# (1 mark)
df_studentsGPASorted = df_studentGrades.sort_values(by='GPA', ascending=False)
print(df_studentsGPASorted)
# Out:
#    firstName  lastName studentID  englishGrade  mathGrade   GPA
# 0       Emma     Smith     10959          95.0       90.0  92.5
# 12      Sara       Doe     47991          98.0       86.0  92.0
# 1     Sophia  Robinson     75175          88.0       95.0  91.5
# 9       Anne     Clark     90449          82.0       99.0  90.5
# 10      Ryan    Thomas     62137          92.0       89.0  90.5
# 4    Stephen     Curry     30303          90.0       88.0  89.0
# 11    Daniel     White     25477          91.0       87.0  89.0
# 8      Sarah     Swift     61026          80.0       98.0  89.0
# 3      David  Robinson     55148          86.0       87.0  86.5
# 2       Emma    Taylor     42257          87.0       85.0  86.0
# 7      James     Jones     87707          76.0       92.0  84.0
# 5   Isabella  Thompson     72824          88.0       79.0  83.5
# 13   Matthew     White     25376          80.0       85.0  82.5
# 6    Jasmine     Smith     70385          84.0       80.0  82.0

# %%
# If we wanted to access the student with the highest gpa based on df_studentsGPASorted,
# does .iloc or .loc make more sense and why?
# (2 marks)

# Using .loc is better when you know the labels of the rows/comlumns that you want to access,
# whereas .iloc is used for integer-location based indexing. In this situation, since we know that
# we have sorted the DataFrame by GPA in descending order, we know that the student in position [0]
# has the highest grade, so we can use .iloc[0] to access the first row

# %%
# Now using the method you specified, assign the variable below to the row containing the student with the highest GPA
# (1 mark)
top_student = df_studentsGPASorted.iloc[0]
print(top_student)
# Out:
# firstName        Emma
# lastName        Smith
# studentID       10959
# englishGrade     95.0
# mathGrade        90.0
# GPA              92.5
# Name: 0, dtype: object

# %%
# Now print the student first name and last name with the highest GPA in this format:
# "The student with the highest GPA is <firstName> <lastName> with a GPA of <GPA>"
# (1 mark)
print(f"The student with the highest GPA is {top_student['firstName']} {top_student['lastName']} with a GPA of {top_student['GPA']}")
# Out:
# The student with the highest GPA is Emma Smith with a GPA of 92.5

# %%
# We can use logical expressions to filter and print data. For example, let's print the students with math grades higher than 90:
df_mathGrade_over90 = df_studentsGPASorted[df_studentsGPASorted['mathGrade'] > 90]
print(df_mathGrade_over90)
# Out:
#   firstName  lastName studentID  englishGrade  mathGrade   GPA
# 1    Sophia  Robinson     75175          88.0       95.0  91.5
# 9      Anne     Clark     90449          82.0       99.0  90.5
# 8     Sarah     Swift     61026          80.0       98.0  89.0
# 7     James     Jones     87707          76.0       92.0  84.0

# %%
# Use logical expressions, and print the students with math grades higher than 90, english grades higher than 80, and GPA greater than 85
df_bestStudents = df_studentsGPASorted[(df_studentsGPASorted['mathGrade'] > 90) & (df_studentsGPASorted['englishGrade'] > 80) & (df_studentsGPASorted['GPA'] > 85)]
print(df_bestStudents)
# Out:
#   firstName  lastName studentID  englishGrade  mathGrade   GPA
# 1    Sophia  Robinson     75175          88.0       95.0  91.5
# 9      Anne     Clark     90449          82.0       99.0  90.5

# %%
# Now print the students whos GPA are lower than 85
# (2 marks)
df_below85GPA = df_studentsGPASorted[df_studentsGPASorted['GPA'] < 85]
print(df_below85GPA)
# Out:
#    firstName  lastName studentID  englishGrade  mathGrade   GPA
# 7      James     Jones     87707          76.0       92.0  84.0
# 5   Isabella  Thompson     72824          88.0       79.0  83.5
# 13   Matthew     White     25376          80.0       85.0  82.5
# 6    Jasmine     Smith     70385          84.0       80.0  82.0

# %%
# Print the Top 3 Performers (highest GPA)
print(df_studentsGPASorted.head(3))
# Out:
#    firstName  lastName studentID  englishGrade  mathGrade   GPA
# 0       Emma     Smith     10959          95.0       90.0  92.5
# 12      Sara       Doe     47991          98.0       86.0  92.0
# 1     Sophia  Robinson     75175          88.0       95.0  91.5

# %%
# Print the Bottom 2 Performers (lowest GPA)
print(df_studentsGPASorted.tail(2))
# Out:
#    firstName lastName studentID  englishGrade  mathGrade   GPA
# 13   Matthew    White     25376          80.0       85.0  82.5
# 6    Jasmine    Smith     70385          84.0       80.0  82.0

# %% [markdown]
# ## Part 4: More Data Analytics using Pandas
# ### (18 marks)

# %%
# Select the column 'grade' from the original English grade dataset and print it
print(df_english['grade'])
# Out:
# 0     95
# 1     88
# 2     87
# 3     86
# 4     90
# 5     88
# 6     84
# 7     76
# 8     80
# 9     82
# 10    92
# 11    91
# 12    98
# 13    80
# Name: grade, dtype: int64

# %%
# Select the column 'GPA' from the df_studentGrades and print it
print(df_studentGrades['GPA'])
# Out:
# 0     92.5
# 1     91.5
# 2     86.0
# 3     86.5
# 4     89.0
# 5     83.5
# 6     82.0
# 7     84.0
# 8     89.0
# 9     90.5
# 10    90.5
# 11    89.0
# 12    92.0
# 13    82.5
# Name: GPA, dtype: float64

# %%
# What is the data type of grade from the English grade dataset?
# (0.5 mark)
#int64

# What is the data type of GPA from the merged dataset?
# (0.5 mark)
#float64

# Is it different? Why?
# (1 mark)
# Yes it is different, because the 'grade' column in the English dataset contains integer values,
# while the 'GPA' column in the merged dataset contains float values because it is calculated as an average,
# and float data type can have decimal points, whereas int cannot.

# %%
# Load the student homeroom CSV file into a DataFrame using the following variable name
# (1 mark)
df_homeroom = pd.read_csv(r"C:\Users\quin4\OneDrive\Documents\UofC_Masters\ENGG680_python\Assignment files\Assignment_1\Github_cloned\ENGG680_2025_Fall\Lab_Assignment_1\studentHomerooms.csv")

# %%
# Print first 5 rows of df_homeroom using the .head method
print(df_homeroom.head(5))
# Out:
#   firstName  lastName  studentID  homeRoom
# 0      Emma     Smith      10959       313
# 1    Sophia  Robinson      75175       311
# 2      Emma    Taylor      42257       311
# 3     David  Robinson      55148       313
# 4   Stephen     Curry      30303       313

# %%
# Merge the studentHomerooms with the merged dataset & name it df_studentInfo. Make sure that the key you are joining on are the same typecast for both datasets.
# Also ensure that there are no redundant columns, and finally display the first few rows.
# Hint: try joining on more than one column to avoid having to drop redundant columns, ie. on=['studentID', '<ColumnA>', '<ColumnB>'] ...
# (5 marks)
#print(df_homeroom.dtypes)
#print(df_studentGrades.dtypes)
df_studentGrades['studentID'] = df_studentGrades['studentID'].astype(int)
df_studentInfo = pd.merge(df_studentGrades, df_homeroom, on=['firstName', 'lastName', 'studentID'])
print(df_studentInfo.head(14))
# Out:
#    firstName  lastName  studentID  englishGrade  mathGrade   GPA  homeRoom
# 0       Emma     Smith      10959          95.0       90.0  92.5       313
# 1     Sophia  Robinson      75175          88.0       95.0  91.5       311
# 2       Emma    Taylor      42257          87.0       85.0  86.0       311
# 3      David  Robinson      55148          86.0       87.0  86.5       313
# 4    Stephen     Curry      30303          90.0       88.0  89.0       313
# 5   Isabella  Thompson      72824          88.0       79.0  83.5       311
# 6    Jasmine     Smith      70385          84.0       80.0  82.0       313
# 7      James     Jones      87707          76.0       92.0  84.0       313
# 8      Sarah     Swift      61026          80.0       98.0  89.0       311
# 9       Anne     Clark      90449          82.0       99.0  90.5       311
# 10      Ryan    Thomas      62137          92.0       89.0  90.5       313
# 11    Daniel     White      25477          91.0       87.0  89.0       311
# 12      Sara       Doe      47991          98.0       86.0  92.0       311
# 13   Matthew     White      25376          80.0       85.0  82.5       313

# %%
# The code below calculates the mean of each homeroom class.
df_grouped = df_studentInfo.groupby('homeRoom')['GPA'].mean()
print(df_grouped)
# Which homeroom has a higher GPA?
# (1 mark)
# Homeroom 311 has a higher GPA
# Out:
# homeRoom
# 311    88.785714
# 313    86.714286
# Name: GPA, dtype: float64

# %%
# Now let's work with multiple sorts. The .sort_values() method can sort by multiple columns, meaning you can specify a primary column and a secondary column for sorting.
# For example, by=['ColumnA', 'ColumnB'] will first sort by ColumnA and then by ColumnB.
# Create and print a DataFrame, df_studentsGPASorted_homeroom, which is sorted by homeRoom and then by GPA, both in descending order.
# (3 mark)
df_studentsGPASorted_homeroom = df_studentInfo.sort_values(by=['homeRoom', 'GPA'], ascending=[False, False])
print(df_studentsGPASorted_homeroom)
# Out:
#    firstName  lastName  studentID  englishGrade  mathGrade   GPA  homeRoom
# 0       Emma     Smith      10959          95.0       90.0  92.5       313
# 10      Ryan    Thomas      62137          92.0       89.0  90.5       313
# 4    Stephen     Curry      30303          90.0       88.0  89.0       313
# 3      David  Robinson      55148          86.0       87.0  86.5       313
# 7      James     Jones      87707          76.0       92.0  84.0       313
# 13   Matthew     White      25376          80.0       85.0  82.5       313
# 6    Jasmine     Smith      70385          84.0       80.0  82.0       313
# 12      Sara       Doe      47991          98.0       86.0  92.0       311
# 1     Sophia  Robinson      75175          88.0       95.0  91.5       311
# 9       Anne     Clark      90449          82.0       99.0  90.5       311
# 8      Sarah     Swift      61026          80.0       98.0  89.0       311
# 11    Daniel     White      25477          91.0       87.0  89.0       311
# 2       Emma    Taylor      42257          87.0       85.0  86.0       311
# 5   Isabella  Thompson      72824          88.0       79.0  83.5       311

# %%
# Do you notice a problem with the indices? They are basically meaningless now that we have sorted by homeroom and GPA.

# The code below changes the index of the dataframe so that it is more intuitive.
df_studentsGPASorted_homeroom['studentRank'] = df_studentsGPASorted_homeroom.groupby('homeRoom').cumcount() + 1
df_studentsGPASorted_homeroom['newIndex'] = df_studentsGPASorted_homeroom['homeRoom'].astype(str) + '-' + df_studentsGPASorted_homeroom['studentRank'].astype(str)
df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.set_index('newIndex')
df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.drop(columns=['studentRank'])

#print(df_studentsGPASorted_homeroom)

# %%
# Describe what each coding line in the cell above is doing
# (4 marks)
# The first line creates a new column 'studentRank' that groupd the data by the 'homeRoom' and the cumCount() function numbers each item
# within each group, which usually starts at 0, but the +1 makes it start at 1 to the length of the group. Since we sorted the dataframe by homeRoom and GPA
# in descending order, 'studentRank' will show a 1 in position 0, which corresponds to tne student in room 313 with the highest GPA
# The second line creates a new column 'newIndex' that combines the 'homeRoom' column as a string, with a dash, and the 'studentRank' column as a string to
# create a unique identifier for each student in the format 'homeRoom-studentRank'
# The third line sets the index of the dataframe to the 'newIndex' column, replacing the default integer index with the new unique identifiers
# The fourth line drops the 'studentRank' column since it is no longer needed after creating the new index

# %%
# Given df_studentsGPASorted_homeroom, please find and print the students with the highest GPA in each homeroom using the .loc method.
# (2 marks)

#print(df_studentsGPASorted_homeroom.index)
print(df_studentsGPASorted_homeroom.loc[(df_studentsGPASorted_homeroom.index == "313-1")])
print(df_studentsGPASorted_homeroom.loc[(df_studentsGPASorted_homeroom.index == "311-1")])
# Out:
#          firstName lastName  studentID  englishGrade  mathGrade   GPA  \
# newIndex
# 313-1         Emma    Smith      10959          95.0       90.0  92.5
#
#           homeRoom
# newIndex
# 313-1          313
#          firstName lastName  studentID  englishGrade  mathGrade   GPA  \
# newIndex
# 311-1         Sara      Doe      47991          98.0       86.0  92.0
#
#           homeRoom
# newIndex
# 311-1          311

# %% [markdown]
# ## Part 5: Using Matplotlib for Data Analytics
# ### (12 marks)

# %%
# In the space below, please import the matplotlib library
import matplotlib.pyplot as plt

# %%
# Let's use matplotlib to display a histogram of the grades distribution
# Histograms are useful for seeing the distribution of the students grades

plt.figure(figsize=(10, 6))
plt.hist(df_studentGrades['englishGrade'], bins=10, alpha=0.7, label='English Grades', color='blue')

# Step 1: Use the line above as reference to create a histogram for the math grades
# (1 mark)
plt.hist(df_studentGrades['mathGrade'], bins=10, alpha=0.7, label='math Grades', color='green')

# Step 2: Ensure that your plot is descriptive, so use labels (x and y axis), a title, and a legend.
# Hint: Use the matplotlib .legend(loc='<location>') to add and place the legend.
# You can use 'upper left', 'upper right', 'lower left', and 'lower right' to specify the location.
# (3 marks)
plt.xlabel('Grades (%)')
plt.ylabel('Number of Students')
plt.title('Distribution of Student Grades in English and Math')
plt.legend(loc='upper left')
plt.grid(True)

# Step 3: Use the .savefig('<image_title>'.png) to output an image file of the histogram.
# Please be sure to use a descriptive title!
# (1 mark)
plt.savefig('Histogram_of_Student_Math_English_Grades_Distribution_by_Number_Of_Students.png')

plt.show()

# %%
# Let's also use matplotlib to display a scatter plot of English vs. Math grades
# Scatter plots are useful for seeing the relationship between two variables
plt.figure(figsize=(10, 6))

# Step 1: Use .scatter(x_data, y_data) to create a scatter plot using the English grades on the x-axis, and Math grades on the y-axis
# (2 mark)
plt.scatter(df_studentGrades['englishGrade'], df_studentGrades['mathGrade'], color='purple', alpha=0.5)

# Step 1: Properly label the x and y axes as well as the title of your plot.
# (3 marks)
plt.xlabel('English Grades (%)')
plt.xlim(75, 100)
plt.ylabel('Math Grades (%)')
plt.title('Relationship Between English and Math Grades')
plt.grid(True)

# Step 2: Output an image file for the scatter plot with a descriptive file name
# (1 mark)
plt.savefig('Scatter_Plot_of_English_vs_Math_Grades.png')

plt.show()

# %%
# From the scatter plot, is there a relationship between the Math and English grades?
# (1 mark)
# The distribution of points in the scatter plot suggests that there is no strong relationship between Math and English grades,
# as the points are widely scattered without a clear pattern or trend.

# %% [markdown]
# ## Part 6: Linear LSE
# ### (35 marks)

# %% [markdown]
# ### Curve Fitting

# %% [markdown]
# ![curvefitting.png](data:image/png;base64,...)

# %% [markdown]
# ### Observations: values of a function f(a) in range of -π to π, contaminated with random noise

# %% [markdown]
# ### Unknown States: coefficients of polynomial functions for curve fitting

# %%
# step 1
# import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# step 2
# Load data.xlsx file, which contains the observations (with noise), variance of observations and true observations
# hint: use pandas library to parse excel file and use numpy library to convert it to array
# (1 mark)
#df_data = #...
#arr_data = #...
df_data = pd.read_excel(r"C:\Users\aggom\OneDrive\文档\GitHub\ENGG680_2025_Fall_Quinn\Lab_Assignment_1\data.xlsx")
arr_data = df_data.to_numpy()
#store the noisy observations, variance of observations and true observations into numpy arrays seperately
# (1 mark)
#l = #...
#l_var = #...
#l_true = #...
l = arr_data[:, 0]
l_var = arr_data[:, 1]
l_true = arr_data[:, 2]

# %%
# step 3
# define the number of observation n
# (1 mark)
#n = #...
n = len(l)

# define the observation weight matrix P for LSE as identity matrix
# identity weight matrix simply means the observations will be unweighted in the following LSE
# (1 mark)
#P = #...
P = np.eye(n)

# define the range of function input(i.e., constants a), from start to end; and the numerical array of a
#start = -1* np.pi
start = -1 * np.pi
#end = np.pi
end = np.pi
#a = np.linspace(start, end, n)
a = np.linspace(start, end, n)

# %%
# step 4
# use the matplotlib to plot the true and noisy observations together in one single figure
# use scatter for noisy observation plotting
# for the true observation, label it as "f(a)"" and set color as 'k'
# for the noisy observation scatter plot, label it as "f(a) + e", set color as 'tab:blue', set marker as 'o' and set alpha as 0.3
# include proper axis labels, legend and title
# scale the range of x-axis to be -1 to 1
# keep this format for the rest of the plots in this lab assignment
# (2 marks)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))
ax.plot(a, l_true, label='f(a)', color='k')
ax.scatter(a, l, label='f(a) + e', color='tab:blue', marker='o', alpha=0.3)
ax.set_xlabel('a')
ax.set_ylabel('Observations')
ax.set_title('True vs Noisy Observations')
ax.set_xlim(-1, 1)
ax.legend(loc='upper left')
# ...

ax.grid(True, which='both',ls='-',color='0.65')
fig.tight_layout()

# %%
# step 5
# define a curve fitting function named fit_polynomial_curve
# the function should implement the linear least square estimation
# the function should include all important intermediate steps in LSE
# the input and output of the funciton are described in the comment below in red.
# please keep code clean and well-commented
# (7 marks)

def fit_polynomial_curve(a: np.ndarray, l: np.ndarray, P: np.ndarray, deg: int) -> tuple:
    '''
    Args:
        a:              function input (constants)
        l:              noisy observations
        P:              observation weight matrix
        deg:            degree of polynomial to fit to data
    Returns:
        x:              estimated polynomial coefficients
        cov_x:          uncertainty in estimated coefficients
        apv:            a posterier variance factor (goodness of fit)
        v:              observation residuals
    '''

  #...
    # number of observations
    n = len(l)

    # design matrix H construction
    H = np.vander(a, N=deg + 1, increasing=True)

    # LSE solution for estimated polynomial coefficients x
    HT_P = H.T @ P
    x = np.linalg.inv(HT_P @ H) @ HT_P @ l

    # calculate observation residuals v
    v = l - H @ x

    # calculate a posteriori variance factor apv
    dof = n - (deg + 1)  # degrees of freedom
    apv = (v.T @ P @ v) / dof

    # calculate covariance of estimated coefficients cov_x
    cov_x = apv * np.linalg.inv(HT_P @ H)

    return (x, cov_x, apv, v)

  #return (x, cov_x, apv, v)

# %%
# step 6
# call the fit_polynomial_curve function and fetch the results
# use polynomial degrees of: 2, 4, 6
# (1 marks)
# ...
deg_list = [2, 4, 6]
results = {}
for deg in deg_list:
    results[deg] = fit_polynomial_curve(a, l, P, deg)

# %%
# step 7
# use the estimated coefficients x and constants array a, construct polynomial functions for each degree
# hint: use polyval function from numpy library (check input argument carefully)
# (1 marks)

#quadratic_uw = #...
#quartic_uw = #...
#hexic_uw = #...
quadratic_uw = np.polyval(results[2][0][::-1], a)
quartic_uw = np.polyval(results[4][0][::-1], a)
hexic_uw = np.polyval(results[6][0][::-1], a)

# %%
# step 8
# use the matplotlib to plot each polynomial function, noisy observations l, true observations l_true, together in one single figure
# for the polynomials of line, cubic and quintic, use color of orange, green and red respectively.
# (2 marks)

# for the polynomials of line, cubic and quintic, use color of orange, green and red respectively.
deg_list_odd = [1, 3, 5] # we have included 1, 3, 5 and 2, 4, 6 since the degrees for line, cubic and quintic are actually 2, 4, 6 
results_odd = {}
for deg in deg_list_odd:
    results_odd[deg] = fit_polynomial_curve(a, l, P, deg)

linear_uw = np.polyval(results_odd[1][0][::-1], a)
cubic_uw = np.polyval(results_odd[3][0][::-1], a)
quintic_uw = np.polyval(results_odd[5][0][::-1], a)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))
ax.plot(a, l_true, label='f(a)', color='k')
ax.scatter(a, l, label='f(a) + e', color='tab:blue', marker='o', alpha=0.3)
ax.plot(a, linear_uw, label='Degree 1 Polynomial', color='orange')
ax.plot(a, cubic_uw, label='Degree 3 Polynomial', color='green')
ax.plot(a, quintic_uw, label='Degree 5 Polynomial', color='red')
ax.set_xlabel('a')
ax.set_ylabel('Observations')
ax.set_title('Polynomial Curve Fitting using LSE')
ax.set_xlim(-1, 1)
ax.legend()

ax.grid(True, which='both',ls='-',color='0.65')
fig.tight_layout()
plt.show()

""" for the polynomial of quadratic, quartic and hexic, use color of orange, green and red respectively.
for additional clarity as we used quadratic, quartic and hexic in steps 6 & 7 """
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))
ax.plot(a, l_true, label='f(a)', color='k')
ax.scatter(a, l, label='f(a) + e', color='tab:blue', marker='o', alpha=0.3)
ax.plot(a, quadratic_uw, label='Degree 2 Polynomial', color='orange')
ax.plot(a, quartic_uw, label='Degree 4 Polynomial', color='green')
ax.plot(a, hexic_uw, label='Degree 6 Polynomial', color='red')
ax.set_xlabel('a')
ax.set_ylabel('Observations')
ax.set_title('Polynomial Curve Fitting using LSE')
ax.set_xlim(-1, 1)
ax.legend()

ax.grid(True, which='both',ls='-',color='0.65')
fig.tight_layout()
plt.show()

# %%
# step 9
# print the a posterier variance factor for each polynomial function
# (3 marks)
# ...
print("For degree 2, 4, 6 polynomials: ")
for deg in deg_list:
    print(f"A posteriori variance factor for degree {deg} polynomial: {results[deg][2]}")
print()

""" added the deg_list_odd results for clarity as we used degree 1, 3, and 5 polynomials in step 8 """
print("For degree 1, 3, 5 polynomials: ")
for deg in deg_list_odd:
    print(f"A posteriori variance factor for degree {deg} polynomial: {results_odd[deg][2]}")
# Out:
# For degree 2, 4, 6 polynomials:
# A posteriori variance factor for degree 2 polynomial: 163.0561531810196
# A posteriori variance factor for degree 4 polynomial: 66.2484281729172
# A posteriori variance factor for degree 6 polynomial: 63.85863154212096
#
# For degree 1, 3, 5 polynomials:
# A posteriori variance factor for degree 1 polynomial: 162.742608604322
# A posteriori variance factor for degree 3 polynomial: 66.13227783131883
# A posteriori variance factor for degree 5 polynomial: 63.7583446301842

# %%
# step 10
# compute and print the norm between the predicted observations (output from each polynomial function) and the true observations
# (3 marks)
# ...
from numpy.linalg import norm

print("For degree 2, 4, 6 polynomials: ")
for deg in deg_list:
    predicted_obs = np.polyval(results[deg][0][::-1], a)
    observation_norm = norm(predicted_obs - l_true)
    print(f"Norm between predicted observations and true observations for degree {deg} polynomial: {observation_norm}")
print()

""" added the deg_list_odd results for clarity as we used degree 1, 3, and 5 polynomials in step 8 """
print("For degree 1, 3, 5 polynomials: ")
for deg in deg_list_odd:
    predicted_obs = np.polyval(results_odd[deg][0][::-1], a)
    observation_norm = norm(predicted_obs - l_true)
    print(f"Norm between predicted observations and true observations for degree {deg} polynomial: {observation_norm}")
# Out:
# For degree 2, 4, 6 polynomials:
# Norm between predicted observations and true observations for degree 2 polynomial: 229.07525292632084
# Norm between predicted observations and true observations for degree 4 polynomial: 38.39862130171957
# Norm between predicted observations and true observations for degree 6 polynomial: 17.777307373989135
#
# For degree 1, 3, 5 polynomials:
# Norm between predicted observations and true observations for degree 1 polynomial: 229.0601679674409
# Norm between predicted observations and true observations for degree 3 polynomial: 38.285979929116536
# Norm between predicted observations and true observations for degree 5 polynomial: 17.369967196967227

# %%
# step 11
# comment on the results of a posterier variance factor and norm, what pattern do you observe
# (2 marks)
# ...
""" As the degree of the polynomial increases, both the a posteriori variance factor and the norm between predicted observations
and true observations tend to decrease. This indicates that higher-degree polynomials provide a better fit to the noisy data,
resulting in lower residual errors and improved accuracy in approximating the true underlying function. However,
it is important to note that excessively high-degree polynomials may lead to overfitting, 
where the model captures noise in the data rather than the true signal. """
# Out:
# ' As the degree of the polynomial increases, both the a posteriori variance factor and the norm between predicted observations\nand true observations tend to decrease. This indicates that higher-degree polynomials provide a better fit to the noisy data,\nresulting in lower residual errors and improved accuracy in approximating the true underlying function. However,\nit is important to note that excessively high-degree polynomials may lead to overfitting, \nwhere the model captures noise in the data rather than the true signal. '

# %%
# step 12
# now, let's define the P matrix with the proper weights of observation
# use the variance of observation l_var, define P matrix
# (1 mark)
#P = #...
P = np.diag(1 / l_var)

# %%
# step 13
# repeat the steps 6-10, using the proper P matrix
# (7 marks)
# ...

# --- 1. Calculate Weighted LSE for ALL Degrees (Steps 6 & 7) ---

# Calculate for even degrees 2, 4, 6
results_weighted = {}
for deg in deg_list:
    results_weighted[deg] = fit_polynomial_curve(a, l, P, deg)

# Calculate for odd degrees 1, 3, 5
results_weighted_odd = {}
for deg in deg_list_odd:
    results_weighted_odd[deg] = fit_polynomial_curve(a, l, P, deg)

# Create prediction arrays (Step 7)
# Using dictionary comprehension for conciseness
predictions_weighted = {deg: np.polyval(results_weighted[deg][0][::-1], a) for deg in deg_list}
predictions_weighted_odd = {deg: np.polyval(results_weighted_odd[deg][0][::-1], a) for deg in deg_list_odd}

# --- 2. Print Norm and APV for EVEN Degrees (2, 4, 6) FIRST (Steps 9 & 10) ---
print ("\n[Weighted LSE Results for Even Degrees]")
for deg in deg_list:
    # Print norm (Step 10)
    observation_norm_weighted = norm(predictions_weighted[deg] - l_true)
    print(f"Norm between predicted observations and true observations for degree {deg} polynomial: {observation_norm_weighted}")
    # Print APV (Step 9)
    print(f"A posteriori variance factor for degree {deg} polynomial: {results_weighted[deg][2]}")
    print()  # Blank line for readability

# --- 3. Print Norm and APV for ODD Degrees (1, 3, 5) NEXT (Steps 9 & 10) ---
print ("\n[Weighted LSE Results for Odd Degrees]")
for deg in deg_list_odd:
    # Print norm (Step 10)
    observation_norm_weighted_odd = norm(predictions_weighted_odd[deg] - l_true)
    print(f"Norm between predicted observations and true observations for degree {deg} polynomial: {observation_norm_weighted_odd}")
    # Print APV (Step 9)
    print(f"A posteriori variance factor for degree {deg} polynomial: {results_weighted_odd[deg][2]}")
    print()  # Blank line for readability

# --- 4. Plot Weighted LSE Results (Similar to Step 8) ---

# Plot 1: Even Degrees (2, 4, 6)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))
ax.plot(a, l_true, label='f(a)', color='k')
ax.scatter(a, l, label='f(a) + e', color='tab:blue', marker='o', alpha=0.3)

for deg in deg_list:
    pred = predictions_weighted[deg]
    color = ('orange' if deg == 2 else 'green' if deg == 4 else 'red')
    ax.plot(a, pred, label=f'Degree {deg} Polynomial', color=color)

ax.set_xlabel('a')
ax.set_ylabel('Observations')
ax.set_title('Weighted Polynomial Curve Fitting using LSE')
ax.set_xlim(-1, 1)
ax.legend()
ax.grid(True, which='both',ls='-',color='0.65')
fig.tight_layout()
plt.show()

# Plot 2: Odd Degrees (1, 3, 5)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))
ax.plot(a, l_true, label='f(a)', color='k')
ax.scatter(a, l, label='f(a) + e', color='tab:blue', marker='o', alpha=0.3)

for deg in deg_list_odd:
    pred = predictions_weighted_odd[deg]
    color = ('orange' if deg == 1 else 'green' if deg == 3 else 'red')
    ax.plot(a, pred, label=f'Degree {deg} Polynomial', color=color)

ax.set_xlabel('a')
ax.set_ylabel('Observations')
ax.set_title('Weighted Polynomial Curve Fitting using LSE')
ax.set_xlim(-1, 1)
ax.legend()
ax.grid(True, which='both',ls='-',color='0.65')
fig.tight_layout()
plt.show()
# Out:
# [Weighted LSE Results for Even Degrees]
# Norm between predicted observations and true observations for degree 2 polynomial: 230.80021355007958
# A posteriori variance factor for degree 2 polynomial: 12.072979326943319
#
# Norm between predicted observations and true observations for degree 4 polynomial: 36.25554580453538
# A posteriori variance factor for degree 4 polynomial: 1.144186704225317
#
# Norm between predicted observations and true observations for degree 6 polynomial: 6.553038055119758
# A posteriori variance factor for degree 6 polynomial: 0.9449284277963491
#
#
# [Weighted LSE Results for Odd Degrees]
# Norm between predicted observations and true observations for degree 1 polynomial: 230.67760813832948
# A posteriori variance factor for degree 1 polynomial: 12.054651233436907
#
# Norm between predicted observations and true observations for degree 3 polynomial: 36.070266872667844
# A posteriori variance factor for degree 3 polynomial: 1.1444647026537134
#
# Norm between predicted observations and true observations for degree 5 polynomial: 5.741606915886474
# A posteriori variance factor for degree 5 polynomial: 0.944700904385655

# %%
# step 14
# Compare the results of a posterier variance factor and norm from unweighted LSE and weighted LSE, what phenomena do you observe? Explain this phenomena.
# (2 marks)
# ...
""" Comparing the results of a posteriori variance factor and norm from unweighted LSE and weighted LSE,
we observe that the weighted LSE generally provides a better fit to the data, as indicated by lower norm values.
This is likely due to the fact that the weighted LSE takes into account the varying uncertainties in the observations,
allowing it to focus more on the regions of the data where we have higher confidence.
In contrast, the unweighted LSE treats all observations equally, which can lead to suboptimal fitting in the presence of noise.
Overall, the use of weights in the LSE formulation appears to enhance the robustness and accuracy of the polynomial fitting process."""
# Out:
# ' Comparing the results of a posteriori variance factor and norm from unweighted LSE and weighted LSE,\nwe observe that the weighted LSE generally provides a better fit to the data, as indicated by lower norm values.\nThis is likely due to the fact that the weighted LSE takes into account the varying uncertainties in the observations,\nallowing it to focus more on the regions of the data where we have higher confidence.\nIn contrast, the unweighted LSE treats all observations equally, which can lead to suboptimal fitting in the presence of noise.\nOverall, the use of weights in the LSE formulation appears to enhance the robustness and accuracy of the polynomial fitting process.'
